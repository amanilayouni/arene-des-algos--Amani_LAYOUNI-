# %% [markdown]
# <a href="https://colab.research.google.com/github/amanilayouni/arene-des-algos--Amani_LAYOUNI-/blob/main/arene_des_algos(J3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/amanilayouni/arene-des-algos--Amani_LAYOUNI-.git
# Out:
# fatal: destination path 'arene-des-algos--Amani_LAYOUNI-' already exists and is not an empty directory.

# %%
# %cd arene-des-algos--Amani_LAYOUNI-
# Out:
# /content/arene-des-algos--Amani_LAYOUNI-

# %%
# !mkdir j3

# %%
# !ls
# Out:
# arene_ml.ipynb	j3  README2.md	README.md  telco_churn.ipynb

# %%
# %cd j3
# Out:
# /content/arene-des-algos--Amani_LAYOUNI-/j3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

print("Imports OK")
# Out:
# Imports OK

# %%
import sklearn

print("Pandas :", pd.__version__)
print("Numpy :", np.__version__)
print("Scikit-Learn :", sklearn.__version__)
# Out:
# Pandas : 2.2.2
# Numpy : 2.0.2
# Scikit-Learn : 1.6.1
